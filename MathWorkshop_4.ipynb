# %% [markdown]
# <a href="https://colab.research.google.com/github/sosamonddr-crypto/MathWorkshop/blob/main/MathWorkshop_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sonal Manandhar UNI ID:2615878

# %% [markdown]
# Example 1
#
# 1. Scatter
# Scatter graphs will plot one point per observation, we can use these to graph independent
# variables to see if there is a correlation. Python will require two sets of variables for a scatter
# graph, one for the x-axis and another for the corresponding y axis. These sets will need to be of
# the same length and work best as lists, array, or array-like data types. We can call ‘pyplot’ to plot
# a scatter with the pyplot.scatter(x,y) call for example

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8,9]
y=[3,4,5,6,7,8,9,10,11]
#plt.plot(x,y)
plt.scatter(x,y,color='red',marker='^')
plt.show()

# %% [markdown]
# Example 2

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8,9]
y=[3,4,5,6,7,1,9,2,5]
#plt.plot(x,y)
plt.scatter(x,y,color='red',marker='^')
x1=[1,5,6,8,12]
y1=[2,6,7,11,13]
plt.scatter(x1,y1,color='blue',marker='s')
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.title("Scatter plot")
plt.show()

# %% [markdown]
# Task-1:
# Create a scatter graph of 10 random x and y values between 0 and 50. Label the axis to show
# x – Time taken in seconds
# y – Distance reached
# Title “Buzzer Game Results”
# One you have a working program, add the following code to your program;
# colors=["red","green","blue","yellow","pink","orange","purple","brown"
# ,"cyan","magenta"]
# And add to your scatter() call the ‘c=colors’ argument like so;
# plt.scatter(x, y, c=colors)
# What happens?

# %%
import matplotlib.pyplot as plt
import random

# Generate 10 random values between 0 and 50
x = [random.randint(0, 50) for _ in range(10)]
y = [random.randint(0, 50) for _ in range(10)]

# Colors list
colors = ["red","green","blue","yellow","pink","orange","purple","brown",
          "cyan","magenta"]

# Scatter plot
plt.scatter(x, y, c=colors)

# Labels and title
plt.xlabel("Time taken in seconds")
plt.ylabel("Distance reached")
plt.title("Buzzer Game Results")

plt.show()

# %% [markdown]
# Example 3

# %%
import matplotlib.pyplot as plt
y=[100,205,307,409,200]
groups=['Pulsar','Duke','Enfield','Honda','Hero']
plt.pie(y,labels=groups)
plt.show()

# %% [markdown]
# Task 2:
# Following data shows the change in population of different animals from 2017 to 2022.
# a. Create a pie chart for the population of each year
# b. Can we show all the pie chart on the single pane? Write the code

# %%
import matplotlib.pyplot as plt

animals = ["Dogs", "Cats", "Rabbits", "Birds"]

data = {
    2017: [20, 25, 15, 10],
    2018: [22, 28, 18, 12],
    2019: [25, 30, 20, 15],
    2020: [28, 35, 22, 18],
    2021: [30, 38, 25, 20],
    2022: [35, 40, 28, 22]
}

# Create all pie charts in one pane
plt.figure(figsize=(12, 8))

i = 1
for year, values in data.items():
    plt.subplot(2, 3, i)
    plt.pie(values, labels=animals, autopct='%1.1f%%')
    plt.title(str(year))
    i += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# Task 3:
# Construct a pie chart to visually display the favorite fruits of the students in a class based on the
# given data: Mango - 45; Orange - 30; Plum - 15; Pineapple - 30; Melon – 30

# %%
import matplotlib.pyplot as plt


fruits = ["Mango", "Orange", "Plum", "Pineapple", "Melon"]
values = [45, 30, 15, 30, 30]

plt.pie(values, labels=fruits, autopct='%1.1f%%')
plt.title("Favorite Fruits of Students")

plt.show()

# %% [markdown]
# Example 4

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
data = [23, 45, 56, 78, 213]
plt.bar(x, data,width=0.5,color='maroon')
plt.title("A bar plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Task 4

# %% [markdown]
# Here is some data to use for the tasks.
#
# Car-color Number seen Red 123 Silver 230 Blue 78 White 193 Green 12

# %%
import matplotlib.pyplot as plt

cars = ["Red", "Silver", "Blue", "White", "Green"]
numbers = [123, 230, 78, 193, 12]

plt.bar(cars, numbers)
plt.title("Car Colors Seen")
plt.xlabel("Car Colors")
plt.ylabel("Number Seen")

plt.show()

# %% [markdown]
# b. Implement the code “ plt.bar(x, y, width = 0.3)” to plot the bar chart, what is the effect?
#
# ans: the width=0.3 makes the bar in the graph thinner

# %%
plt.bar(cars, numbers, width=0.3)
plt.show()

# %% [markdown]
# c. Implement the code “ plt.barh(x, y)” to plot the bar chart, what is the effect?
#
# ans: The code makes the bar go from left to right horizontally rather tahn up to down vertically.

# %%
plt.barh(cars, numbers)
plt.show()

# %% [markdown]
# d. Create a list of colors and using the “ plt.bar(x, y, color = {you list here} ) “set the bar chart colors to be the same as the car colors each bar represents.

# %%
colors = ["red", "silver", "blue", "white", "green"]
plt.gca().set_facecolor('grey')
plt.bar(cars, numbers, color=colors)
plt.show()

# %% [markdown]
# e. Create a pie chart of the car data above and add a title.

# %%
import matplotlib.pyplot as plt
x=['Red','Silver','Blue','Green']
y=[123,230,78,12]
plt.pie(y,labels=x,colors=x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c898caffb60>,
# ...
#  [Text(0.7073982542963101, 0.842370292578349, 'Red'),
#   Text(-1.0700152724492478, -0.25508296047631723, 'Silver'),
#   Text(0.8245543562243156, -0.728086611353007, 'Blue'),
#   Text(1.0960193423937419, -0.09349652987565805, 'Green')])

# %% [markdown]
# f. Test out the following pie chart additional arguments / settings (“...” is for the normal code you have already)

# %% [markdown]
# A- myexplode = [0.3, 0, 0, 0] plt.pie(... , explode = myexplode)

# %%
import matplotlib.pyplot as plt
x=['Red','Silver','Blue','Green']
y=[123,230,78,12]
myexplode = [0.3, 0, 0,0]
plt.pie(y,labels=x,colors=x,explode = myexplode)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c898c928a70>,
# ...
#  [Text(0.9003250509225764, 1.072107645099717, 'Red'),
#   Text(-1.0700152724492478, -0.25508296047631723, 'Silver'),
#   Text(0.8245543562243156, -0.728086611353007, 'Blue'),
#   Text(1.0960193423937419, -0.09349652987565805, 'Green')])

# %% [markdown]
# B- myexplode = [0.3, 0, 0, 0] plt.pie(... , explode = myexplode,shadow = True)

# %%
import matplotlib.pyplot as plt
x=['Red','Silver','Blue','Green']
y=[123,230,78,12]
myexplode = [0.3, 0, 0,0]
plt.pie(y,labels=x,colors=x,explode = myexplode,shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c898cd8c740>,
# ...
#  [Text(0.9003250509225764, 1.072107645099717, 'Red'),
#   Text(-1.0700152724492478, -0.25508296047631723, 'Silver'),
#   Text(0.8245543562243156, -0.728086611353007, 'Blue'),
#   Text(1.0960193423937419, -0.09349652987565805, 'Green')])

# %% [markdown]
# C- plt.legend(title = "Car Colours:")

# %%
import matplotlib.pyplot as plt
x=['Red','Silver','Blue','Green']
y=[123,230,78,12]
myexplode = [0.3, 0, 0, 0]
plt.legend(title="Car Colours:")
plt.pie(y,labels=x,colors=x,explode = myexplode,shadow = True)
# Out:
# /tmp/ipykernel_594/1584297854.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Car Colours:")
# ([<matplotlib.patches.Wedge at 0x7c898ce0b860>,
# ...
#  [Text(0.9003250509225764, 1.072107645099717, 'Red'),
#   Text(-1.0700152724492478, -0.25508296047631723, 'Silver'),
#   Text(0.8245543562243156, -0.728086611353007, 'Blue'),
#   Text(1.0960193423937419, -0.09349652987565805, 'Green')])

# %% [markdown]
# D- mycolours = ["Magenta", "Green", "Cyan", "Red"] plt.pie(... , colors = mycolours)

# %%
import matplotlib.pyplot as plt
x=['Red','Silver','Blue','Green']
y=[123,230,78,12]
myexplode = [0.3, 0, 0, 0]
mycolours = ["Red","Magenta","Cyan","Green"]
plt.legend(title="Car Colours:")
plt.pie(y,labels=x,colors=mycolours,explode = myexplode,shadow = True)
# Out:
# /tmp/ipykernel_594/1182035244.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Car Colours:")
# ([<matplotlib.patches.Wedge at 0x7c898c9aa930>,
# ...
#  [Text(0.9003250509225764, 1.072107645099717, 'Red'),
#   Text(-1.0700152724492478, -0.25508296047631723, 'Silver'),
#   Text(0.8245543562243156, -0.728086611353007, 'Blue'),
#   Text(1.0960193423937419, -0.09349652987565805, 'Green')])
