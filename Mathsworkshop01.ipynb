# %% [markdown]
# <a href="https://colab.research.google.com/github/sosamonddr-crypto/MathWorkshop/blob/main/Mathsworkshop01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Sonal Manandhar
# UNI ID: 2615878

# %%
lenght = 10 #variable1
width = 5 #variable2
area = lenght * width #formula #this is called an expression
print(area) #print

# %%
#Implicit conversion
base = 6
height = 2
area = base * height / 2
print("Area is " + str(area)) #change, int type, 'area' to string
# Out:
# Area is 6.0

# %%
hrs = input("Enter Hours: ")
h = float(hrs)
rate = input("Enter the rate per hour:")
r = float(rate)
if h<=40:
  pay = h * r
else:
  overtimepay= h - 40
  pay = (40 * rate) + (overtimepay * rate * 1.5)
print("gross pay",pay)
# Out:
# Enter Hours: 2
# Enter the rate per hour:4
# gross pay 8.0

# %%
def greeting (name): #passing parameters/argument to the function
 print("welcome"+name)
greeting("Type_Your_Name")

# %%
def area_traingal(b, h):
  return b*h/2
area = area_traingal(4, 8)
print("area of traingal is: " + str(area))

# %%
def order_numbers(num1, num2):

    if num1 < num2:
        return num1, num2
    else:
        return num2, num1

# %%
#example 7
#Even or odd
def is_Even(number):
  if (number%2 == 0):
    return True
  return False
  is_even(7)

# %%
#example 8
def numner_group(number):
  if number > 0:
    return "Positive"
  elif number == 0:
    return "Zero"
  else:
    return "Negative"
  print(numner_group(10)) #should be positive
  print(numner_group(0)) #should be zero
  print(numner_group(-5) #should be negative
# Out:
#   File "/tmp/ipykernel_230/4012051530.py", line 12
#
#     ^
# SyntaxError: incomplete input

# %% [markdown]
# Loops:
#
# 1.   while

# %%
#while loop
x = 0 #intialzation of variable why=?
while x < 5:
  print("Not there yet, x= " + str(x))
  x = x + 1
print("x= " + str(x)) #output=??
# Out:
# Not there yet, x= 0
# Not there yet, x= 1
# Not there yet, x= 2
# Not there yet, x= 3
# Not there yet, x= 4
# x= 5

# %%
def count_down(start_number):
 current=3 #initialzation of variable
 while (current > 0):
  print (current)
 current -= 1
 print("Zero!")
 count_down(3)

# %%
#Solution of Example 11
if x != 0:
 while x%2 == 0:
    x = x/2
#or
while x != 0 and x%2 == 0:
    x = x/2

# %%
#example 13
# for loop, iterates over a sequence of values
for x in range(5):
 print(x) #Output=??
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Example-14

def square(n):
    return n*n

def sum_squares(x):
    sum = 0
    for n in range(10):
        sum += square(n)
    return sum

print(sum_squares(10))
# Out:
# 285

# %% [markdown]
# Exercise:1
# A
#
# 1. Write a function fib (n) that prompts the number of terms “n” from the user and
# displays first “n” terms of Fibonacci sequence iteratively

# %%
def fib():
    n = int(input("Enter the number of terms: "))
    a, b = 0, 1
    print("Fibonacci sequence:")
    for _ in range(n):
        print(a, end=" ")
        a, b = b, a + b
    print()

# %% [markdown]
# B. Write a function myPow(x, n) that returns 𝑥
# 𝑛
# , where and n is a non-negative integer.
# Do not use the ** operator or the math.pow function - use one while loop.

# %%
def myPow(x, n):
    result = 1
    i = 0
    while i < n:
        result *= x
        i += 1
    return result

# %% [markdown]
# C. Write a function SumDigits(n) that displays the sum of digits of “n”. Hint:
# SumDigits(234) will be 2+3+4=9

# %%
def SumDigits(n):
    total = 0
    num = n
    while num > 0:
        total += num % 10
        num //= 10
    print("Sum of digits of", n, "is", total)

# %% [markdown]
# D. Write a function squaredSum that returns the sum of the squares of an array/list of
# integers such that squaredSum([2,3,4]) gives 29. Write your solution in pure Python
# to show the logic in your solution, do not use any library functions.

# %%
def squaredSum(arr):
    total = 0
    for num in arr:
        total += num * num
    return total

# %% [markdown]
# E. Write a function called sumDigits that is given an integer num and returns the sum of
# the digits of num. Eg. sumDigits(6) gives 21. Do not use any library functions (if
# there is one)

# %%
def sumDigits(num):
    total = 0
    n = num
    while n > 0:
        total += n % 10
        n //= 10
    return total
